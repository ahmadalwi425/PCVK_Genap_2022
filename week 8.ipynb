# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadalwi425/PCVK_Genap_2022/blob/main/week%208.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = np.ones((5,5), np.uint8)
edited = cv2.dilate(original, kernel, iterations = 1)

plt.subplot(121),plt.imshow(original),plt.title('Original')
plt.subplot(122),plt.imshow(edited),plt.title('Dilated')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7bee2d10>,
# ...
#  Text(0.5, 1.0, 'Dilated'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = np.ones((5,5), np.uint8)
edited = cv2.erode(original, kernel, iterations = 1)

plt.subplot(121),plt.imshow(original),plt.title('Original')
plt.subplot(122),plt.imshow(edited),plt.title('Eroded')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7bb07690>,
# ...
#  Text(0.5, 1.0, 'Eroded'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = np.ones((5,5), np.uint8)
edited = cv2.morphologyEx(original, cv2.MORPH_DILATE, kernel)

plt.subplot(121),plt.imshow(original),plt.title('Original')
plt.subplot(122),plt.imshow(edited),plt.title('Morphology Dilation')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7c13a390>,
# ...
#  Text(0.5, 1.0, 'Morphology'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = np.ones((5,5), np.uint8)
edited = cv2.morphologyEx(original, cv2.MORPH_ERODE, kernel)

plt.subplot(121),plt.imshow(original),plt.title('Original')
plt.subplot(122),plt.imshow(edited),plt.title('Morphology Erotion')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7be8f990>,
# ...
#  Text(0.5, 1.0, 'Morphology Erotion'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = np.ones((7,7), np.uint8)
opening = cv2.morphologyEx(original, cv2.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(original), plt.title('Original')
plt.subplot(122), plt.imshow(opening), plt.title('Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7bccb0d0>,
# ...
#  Text(0.5, 1.0, 'Opening'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = np.ones((7,7), np.uint8)
opening = cv2.morphologyEx(original, cv2.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(original), plt.title('Original')
plt.subplot(122), plt.imshow(opening), plt.title('Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7baf4790>,
# ...
#  Text(0.5, 1.0, 'Closing'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3)) 
edited = cv2.dilate(original, kernel, iterations = 1)
plt.subplot(121), plt.imshow(original), plt.title('Original')
plt.subplot(122), plt.imshow(edited), plt.title('dilated')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7b5ee150>,
# ...
#  Text(0.5, 1.0, 'dilated'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(5,5)) 
edited = cv2.dilate(original, kernel, iterations = 1)
plt.subplot(121), plt.imshow(original), plt.title('Original')
plt.subplot(122), plt.imshow(edited), plt.title('dilated')
# Out:
# SED = Cross 3
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7b660e90>,
# ...
#  Text(0.5, 1.0, 'dilated'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(3,3)) 
edited = cv2.dilate(original, kernel, iterations = 1)
plt.subplot(121), plt.imshow(original), plt.title('Original')
plt.subplot(122), plt.imshow(edited), plt.title('dilated')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7b490990>,
# ...
#  Text(0.5, 1.0, 'dilated'))

# %%
original = cv2.imread('/content/drive/MyDrive/kampus/PCVK/j.png')
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5)) 
edited = cv2.dilate(original, kernel, iterations = 1)
plt.subplot(121), plt.imshow(original), plt.title('Original')
plt.subplot(122), plt.imshow(edited), plt.title('dilated')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fab7b36b250>,
# ...
#  Text(0.5, 1.0, 'dilated'))
