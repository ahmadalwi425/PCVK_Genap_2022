# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadalwi425/PCVK_Genap_2022/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Transformasi Linier Brightness
#
# Formula: *g(x,y)=f(x,y)+b*
# *g(x,y)* adalah nilai pixel setelah transformasi, f(x,y) adalah nilai pixel asli, *b* adalah nilai brightness

# %%
print('Change brighness level of image')
print('--------------------------------')
try:
  brightness = int(input('Input brightness level: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/kampus/PCVK/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#access for each pixel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
# Change brighness level of image
# --------------------------------
# Input brightness level: 60
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F714FEA0810>

# %% [markdown]
# TASK

# %%
print('Change brighness level of image')
print('--------------------------------')
try:
  brightness = int(input('Input brightness level: '))
  contrast = float(input('* Enter the contrast level [1.0-3.0]: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/kampus/PCVK/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#access for each pixel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(contrast*original[y,x,c] + brightness, 0, 255)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
# Change brighness level of image
# --------------------------------
# Input brightness level: 60
# * Enter the contrast level [1.0-3.0]: 1.5
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F714FE1A2D0>

# %%
print('Change brighness level of image')
print('--------------------------------')
try:
  brightnessLog = int(input('Input brightness level: '))
except ValueError:
  print('Error, not a number')


original = cv.imread('/content/drive/MyDrive/kampus/PCVK/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#access for each pixel
c = 255 / np.log(1 + np.max(original))
log_image = c * (np.log(original + 1))
log_image = np.array(log_image, dtype = np.uint8)

final_frame = cv.hconcat((original, log_image))
cv2_imshow(final_frame)
# Out:
# Change brighness level of image
# --------------------------------
# Input brightness level: 40
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F714FDC5C90>

# %%
print('Grayscaling of image (Averaging)')
print('--------------------------------')
original = cv.imread('/content/drive/MyDrive/kampus/PCVK/mandrill.tiff')
gray_image = original
grayscale_average_img = np.mean(original, axis=2)
original = cv.imread('/content/drive/MyDrive/kampus/PCVK/mandrill.tiff')
original = cv.cvtColor(original,cv.COLOR_BGR2RGB)
plt.subplot(1, 2, 1)
plt.imshow(original)
plt.subplot(1, 2, 2)
plt.imshow(grayscale_average_img, cmap='gray')
# Out:
# Grayscaling of image (Averaging)
# --------------------------------

# %%
print('Grayscaling of image (Luminosity)')
print('--------------------------------')
original = cv.imread('/content/drive/MyDrive/kampus/PCVK/mandrill.tiff')
gray_image = original
R, G, B = gray_image[:,:,0], gray_image[:,:,1],gray_image[:,:,2]
luminosity = 0.2126 * R + 0.7152 * G + 0.0722 * B
original = cv.imread('/content/drive/MyDrive/kampus/PCVK/mandrill.tiff')
original = cv.cvtColor(original,cv.COLOR_BGR2RGB)
plt.subplot(1, 2, 1)
plt.imshow(original)
plt.subplot(1, 2, 2)
plt.imshow(luminosity, cmap='gray')
# Out:
# Grayscaling of image (Luminosity)
# --------------------------------

# %%
print('Grayscaling of image (Luminosity)')
print('--------------------------------')
original = cv.imread('/content/drive/MyDrive/kampus/PCVK/mandrill.tiff')
gray_image = cv.cvtColor(original,cv.COLOR_BGR2RGB)
gray_image[:,:,1]=0
gray_image[:,:,2]=0
original = cv.imread('/content/drive/MyDrive/kampus/PCVK/mandrill.tiff')
original = cv.cvtColor(original,cv.COLOR_BGR2RGB)
plt.subplot(1, 2, 1)
plt.imshow(original)
plt.subplot(1, 2, 2)
plt.imshow(gray_image)
# Out:
# Grayscaling of image (Luminosity)
# --------------------------------
