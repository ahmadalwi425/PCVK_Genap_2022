# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadalwi425/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/kampus/PCVK/photo-1595433707802-6b2626ef1c91.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/kampus/PCVK/photo-1595433707802-6b2626ef1c91.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
imgTask = cv.imread('/content/drive/MyDrive/kampus/PCVK/colorful-1359948__340.png')
plt.imshow(imgTask)

# %%
imgTaskcvt = cv.cvtColor(imgTask,cv.COLOR_BGR2RGB)
plt.imshow(imgTaskcvt)

# %%
imgTaskcvtGB = imgTaskcvt
imgTaskcvtGB[:,:,0]=0
plt.imshow(imgTaskcvtGB)

# %%
imgTaskcvtRG = imgTaskcvt
imgTaskcvtRG[:,:,2]=0
plt.imshow(imgTaskcvtRG)

# %%
crop = imgTaskcvt[10:100, 10:100] 
plt.imshow(crop)

# %%
crop2 = imgTaskcvt[5:30, 0:img3.shape[1]] 
crop2[:,:,0] = 0
crop2[:,:,2] = 0
plt.imshow(crop2)

# %%
plt.imshow(img3)

# %%
img4= cv.cvtColor(img,cv.COLOR_BGR2RGB)
import random
cv.rectangle(img4,pt1=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),pt2=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),color=(0,255,0),thickness=10)
cv.rectangle(img4,pt1=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),pt2=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),color=(0,0,255),thickness=10)
cv.rectangle(img4,pt1=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),pt2=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),color=(255,0,0),thickness=10)
cv.rectangle(img4,pt1=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),pt2=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),color=(255,0,255),thickness=10)
cv.rectangle(img4,pt1=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),pt2=(random.randint(0,img4.shape[0]),random.randint(0,img4.shape[1])),color=(255,250,0),thickness=10)
plt.imshow(img4)

# %%
plt.imshow(cv.flip(img4,0))

# %%
imgFoto = cv.imread('/content/drive/MyDrive/IMG20210629134002 - Copy.png')
imgFoto2 = imgFoto

imgFoto3 = cv.cvtColor(imgFoto,cv.COLOR_BGR2RGB)
cv.rectangle(imgFoto3,pt1=(random.randint(0,imgFoto.shape[0]),random.randint(0,imgFoto.shape[1])),pt2=(random.randint(0,imgFoto.shape[0]),random.randint(0,imgFoto.shape[1])),color=(0,0,255),thickness=80)
cv.circle(imgFoto3,center=(random.randint(0,imgFoto.shape[0]-500),random.randint(0,imgFoto.shape[1]-500)),radius=500,color=(255,0,0),thickness=80)
plt.imshow(imgFoto3)
